# %% [markdown]
# <a href="https://colab.research.google.com/github/TaniaHafsa/my-github-repo/blob/main/Brain_Stroke_Prediction(Hafsa).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Exploratory Data Analysis(EDA)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in data into a dataframe
data = pd.read_csv('/content/drive/MyDrive/brain_stroke.csv')

# Display top of dataframe
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
# See the column data types and non-missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
#checking for total null values
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# If we see any feature unrelated to label, we can just drop them before starting to EDA and preprocessing

# %%
data = data.drop(["ever_married", "work_type", "Residence_type"], axis =1)

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0    Male  67.0             0              1             228.69  36.6
# 1    Male  80.0             0              1             105.92  32.5
# 2  Female  49.0             0              0             171.23  34.4
# 3  Female  79.0             1              0             174.12  24.0
# 4    Male  81.0             0              0             186.21  29.0
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2           smokes       1
# 3     never smoked       1
# 4  formerly smoked       1

# %% [markdown]
# ## How many of the people in the data had a stroke before? Check the label

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['stroke'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('had stroke')
ax[0].set_ylabel('')
sns.countplot(x='stroke',data=data,ax=ax[1])
ax[1].set_title('had stroke')
plt.show()

# %% [markdown]
# ## Categorical Feature : Gender

# %%
data.groupby(['gender','stroke'])['stroke'].count()
# Out:
# gender  stroke
# Female  0         2767
#         1          140
# Male    0         1966
#         1          108
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['gender','stroke']].groupby(['gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke vs Gender')
sns.countplot(x='gender',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('Gender:Had a Stroke vs Not had a Stroke')
plt.show()

# %% [markdown]
# ## Categorical Feature: Hypertansion

# %%
data.groupby(['hypertension','stroke'])['stroke'].count()
# Out:
# hypertension  stroke
# 0             0         4320
#               1          182
# 1             0          413
#               1           66
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['hypertension','stroke']].groupby(['hypertension']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke vs Having hypertesion')
sns.countplot(x='hypertension',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('hypertension:Had a Stroke vs Not had a Stroke')
plt.show()

# %% [markdown]
# ## Categorical Feature : Heart Disease

# %%
data.groupby(['heart_disease','stroke'])['stroke'].count()
# Out:
# heart_disease  stroke
# 0              0         4505
#                1          201
# 1              0          228
#                1           47
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['heart_disease','stroke']].groupby(['heart_disease']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke vs heart_disease')
sns.countplot(x='heart_disease',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('heart_disease:Had a Stroke vs Not had a Stroke')
plt.show()

# %% [markdown]
# ## Ordinal Feature : Smoking Status

# %%
pd.crosstab(data.smoking_status,data.stroke,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_252a9_row0_col0 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_252a9_row0_col1 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_252a9_row0_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_252a9_row1_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_252a9_row1_col1 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_252a9_row1_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_252a9_row2_col0, #T_252a9_row2_col2 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_252a9_row2_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_252a9_row3_col0, #T_252a9_row3_col1, #T_252a9_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_252a9_row4_col0, #T_252a9_row4_col1, #T_252a9_row4_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_252a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stroke</th>
#       <th id="T_252a9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_252a9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_252a9_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >smoking_status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_252a9_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_252a9_row0_col0" class="data row0 col0" >1453</td>
#       <td id="T_252a9_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_252a9_row0_col2" class="data row0 col2" >1500</td>
#     </tr>
#     <tr>
#       <th id="T_252a9_level0_row1" class="row_heading level0 row1" >formerly smoked</th>
#       <td id="T_252a9_row1_col0" class="data row1 col0" >797</td>
#       <td id="T_252a9_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_252a9_row1_col2" class="data row1 col2" >867</td>
#     </tr>
#     <tr>
#       <th id="T_252a9_level0_row2" class="row_heading level0 row2" >never smoked</th>
#       <td id="T_252a9_row2_col0" class="data row2 col0" >1749</td>
#       <td id="T_252a9_row2_col1" class="data row2 col1" >89</td>
#       <td id="T_252a9_row2_col2" class="data row2 col2" >1838</td>
#     </tr>
#     <tr>
#       <th id="T_252a9_level0_row3" class="row_heading level0 row3" >smokes</th>
#       <td id="T_252a9_row3_col0" class="data row3 col0" >734</td>
#       <td id="T_252a9_row3_col1" class="data row3 col1" >42</td>
#       <td id="T_252a9_row3_col2" class="data row3 col2" >776</td>
#     </tr>
#     <tr>
#       <th id="T_252a9_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_252a9_row4_col0" class="data row4 col0" >4733</td>
#       <td id="T_252a9_row4_col1" class="data row4 col1" >248</td>
#       <td id="T_252a9_row4_col2" class="data row4 col2" >4981</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['smoking_status'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of People had a stroke by smoking status')
ax[0].set_ylabel('Count')
sns.countplot(x='smoking_status',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('Smoking Status:Had a stroke vs Never had a stroke')
plt.show()

# %% [markdown]
# ## Let's also check the relationship between the gender and smoking status on stroke

# %%
pd.crosstab([data.gender,data.stroke],data.smoking_status,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6cda8_row0_col0 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_6cda8_row0_col1 {
#   background-color: #86c266;
#   color: #000000;
# }
# #T_6cda8_row0_col2 {
#   background-color: #63b166;
#   color: #f1f1f1;
# }
# #T_6cda8_row0_col3 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_6cda8_row0_col4 {
#   background-color: #74ba66;
#   color: #f1f1f1;
# }
# #T_6cda8_row1_col0, #T_6cda8_row1_col1, #T_6cda8_row1_col3, #T_6cda8_row3_col0, #T_6cda8_row3_col1, #T_6cda8_row3_col2, #T_6cda8_row3_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6cda8_row1_col2 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_6cda8_row1_col4, #T_6cda8_row3_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_6cda8_row2_col0 {
#   background-color: #8fc766;
#   color: #000000;
# }
# #T_6cda8_row2_col1 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_6cda8_row2_col2 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_6cda8_row2_col3 {
#   background-color: #9cce66;
#   color: #000000;
# }
# #T_6cda8_row2_col4 {
#   background-color: #9ece66;
#   color: #000000;
# }
# #T_6cda8_row4_col0, #T_6cda8_row4_col1, #T_6cda8_row4_col2, #T_6cda8_row4_col3, #T_6cda8_row4_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6cda8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >smoking_status</th>
#       <th id="T_6cda8_level0_col0" class="col_heading level0 col0" >Unknown</th>
#       <th id="T_6cda8_level0_col1" class="col_heading level0 col1" >formerly smoked</th>
#       <th id="T_6cda8_level0_col2" class="col_heading level0 col2" >never smoked</th>
#       <th id="T_6cda8_level0_col3" class="col_heading level0 col3" >smokes</th>
#       <th id="T_6cda8_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="index_name level1" >stroke</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cda8_level0_row0" class="row_heading level0 row0" rowspan="2">Female</th>
#       <th id="T_6cda8_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_6cda8_row0_col0" class="data row0 col0" >783</td>
#       <td id="T_6cda8_row0_col1" class="data row0 col1" >430</td>
#       <td id="T_6cda8_row0_col2" class="data row0 col2" >1132</td>
#       <td id="T_6cda8_row0_col3" class="data row0 col3" >422</td>
#       <td id="T_6cda8_row0_col4" class="data row0 col4" >2767</td>
#     </tr>
#     <tr>
#       <th id="T_6cda8_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_6cda8_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_6cda8_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_6cda8_row1_col2" class="data row1 col2" >62</td>
#       <td id="T_6cda8_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_6cda8_row1_col4" class="data row1 col4" >140</td>
#     </tr>
#     <tr>
#       <th id="T_6cda8_level0_row2" class="row_heading level0 row2" rowspan="2">Male</th>
#       <th id="T_6cda8_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_6cda8_row2_col0" class="data row2 col0" >670</td>
#       <td id="T_6cda8_row2_col1" class="data row2 col1" >367</td>
#       <td id="T_6cda8_row2_col2" class="data row2 col2" >617</td>
#       <td id="T_6cda8_row2_col3" class="data row2 col3" >312</td>
#       <td id="T_6cda8_row2_col4" class="data row2 col4" >1966</td>
#     </tr>
#     <tr>
#       <th id="T_6cda8_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_6cda8_row3_col0" class="data row3 col0" >22</td>
#       <td id="T_6cda8_row3_col1" class="data row3 col1" >36</td>
#       <td id="T_6cda8_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_6cda8_row3_col3" class="data row3 col3" >23</td>
#       <td id="T_6cda8_row3_col4" class="data row3 col4" >108</td>
#     </tr>
#     <tr>
#       <th id="T_6cda8_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_6cda8_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_6cda8_row4_col0" class="data row4 col0" >1500</td>
#       <td id="T_6cda8_row4_col1" class="data row4 col1" >867</td>
#       <td id="T_6cda8_row4_col2" class="data row4 col2" >1838</td>
#       <td id="T_6cda8_row4_col3" class="data row4 col3" >776</td>
#       <td id="T_6cda8_row4_col4" class="data row4 col4" >4981</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize = (15,8))
sns.catplot(x='smoking_status',y='stroke',hue='gender',data=data,kind="point")
plt.show()

# %% [markdown]
# ## Continous Feature: Age

# %%
# See the min, max, mean values
print('Oldest Person was of:',data['age'].max(),'Years')
print('Youngest Person was of:',data['age'].min(),'Years')
print('Average Age in the data:',data['age'].mean(),'Years')
# Out:
# Oldest Person was of: 82.0 Years
# Youngest Person was of: 0.08 Years
# Average Age in the data: 43.41985946597069 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x="smoking_status",y="age", hue="stroke", data=data,split=True,ax=ax[0])
ax[0].set_title('Smoking Status and Age vs Had a stroke')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x="gender",y="age", hue="stroke", data=data,split=True,ax=ax[1])
ax[1].set_title('Gender and Age vs Had a stroke')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# ## Continious Features: Average Glucose Level and BMI (Body Mass Index)

# %%
print('Maximum "Average Glucose Level" in data:',data['avg_glucose_level'].max())
print('Minimum "Average Glucose Level" in data:',data['avg_glucose_level'].min())
print('Average "Average Glucose Level" in data:',data['avg_glucose_level'].mean())
print("***************************************")
print('Maximum "BMI" in data:',data['bmi'].max())
print('Minimum "BMI" in data:',data['bmi'].min())
print('Average "BMI" in data:',data['bmi'].mean())
# Out:
# Maximum "Average Glucose Level" in data: 271.74
# Minimum "Average Glucose Level" in data: 55.12
# Average "Average Glucose Level" in data: 105.94356153382854
# ***************************************
# Maximum "BMI" in data: 48.9
# Minimum "BMI" in data: 14.0
# Average "BMI" in data: 28.498173057618956

# %% [markdown]
# ## Lets see the density of smoke status on the average glucose level in graphs

# %%
f,ax=plt.subplots(1,4,figsize=(20,8))
sns.distplot(data[data['smoking_status']=="formerly smoked"].avg_glucose_level,ax=ax[0])
ax[0].set_title('Smokes status in formerly smoked')
sns.distplot(data[data['smoking_status']=="smokes"].avg_glucose_level,ax=ax[1])
ax[1].set_title('Smokes status in smokes')
sns.distplot(data[data['smoking_status']== "never smoked"].avg_glucose_level,ax=ax[2])
ax[2].set_title('Smokes status in never smokes')
sns.distplot(data[data['smoking_status']== "Unknown"].avg_glucose_level,ax=ax[3])
ax[3].set_title('Smokes status in Unknown')
plt.show()

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # 2. Feature Engineering and Data Cleaning

# %%
data.insert(2,'age_band', np.zeros)

# %%
data.loc[data['age']<=16,'age_band']=0
data.loc[(data['age']>16)&(data['age']<=32),'age_band']=1
data.loc[(data['age']>32)&(data['age']<=48),'age_band']=2
data.loc[(data['age']>48)&(data['age']<=64),'age_band']=3
data.loc[data['age']>64,'age_band']=4
data.drop(columns= "age", inplace=True)
data["age_band"]=data['age_band'].astype(str).astype(int)
data.head()
# Out:
#    gender  age_band  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0    Male         4             0              1             228.69  36.6
# 1    Male         4             0              1             105.92  32.5
# 2  Female         3             0              0             171.23  34.4
# 3  Female         4             1              0             174.12  24.0
# 4    Male         4             0              0             186.21  29.0
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2           smokes       1
# 3     never smoked       1
# 4  formerly smoked       1

# %%
#checking the number of people in each band
data['age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_1c914_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1c914_row1_col0 {
#   background-color: #a5d266;
#   color: #000000;
# }
# #T_1c914_row2_col0 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_1c914_row3_col0 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_1c914_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c914" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c914_level0_col0" class="col_heading level0 col0" >age_band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c914_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_1c914_row0_col0" class="data row0 col0" >1229</td>
#     </tr>
#     <tr>
#       <th id="T_1c914_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1c914_row1_col0" class="data row1 col0" >1067</td>
#     </tr>
#     <tr>
#       <th id="T_1c914_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_1c914_row2_col0" class="data row2 col0" >1020</td>
#     </tr>
#     <tr>
#       <th id="T_1c914_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_1c914_row3_col0" class="data row3 col0" >895</td>
#     </tr>
#     <tr>
#       <th id="T_1c914_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_1c914_row4_col0" class="data row4 col0" >770</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='age_band',y='stroke',data=data,col='smoking_status',kind="point")
plt.show()

# %%
# copy the data
data = data.copy()

# apply normalization techniques on Columns
column = 'avg_glucose_level'
column2 = 'bmi'
data[column] = data[column] /data[column].abs().max()
data[column2] = data[column2] /data[column2].abs().max()

# view normalized data
display(data[column], data[column2])
# Out:
# 0       0.841577
# 1       0.389784
# 2       0.630124
# 3       0.640760
# 4       0.685251
#           ...
# 4976    0.258151
# 4977    0.703430
# 4978    0.349672
# 4979    0.308898
# 4980    0.308199
# Name: avg_glucose_level, Length: 4981, dtype: float64
# 0       0.748466
# 1       0.664622
# 2       0.703476
# 3       0.490798
# 4       0.593047
#           ...
# 4976    0.609407
# 4977    0.635992
# 4978    0.650307
# 4979    0.613497
# 4980    0.595092
# Name: bmi, Length: 4981, dtype: float64

# %% [markdown]
# ## We also need to conver string variables to numeric variables. So, we need to work on smoking_status and gender too.

# %%
data['gender'].replace(['Male','Female'],[0,1],inplace=True)
data['gender'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: gender, dtype: int64

# %%
# What was the smoking status variables
data["smoking_status"].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
data['smoking_status'].replace(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],[0,1,2,3],inplace=True)
data['smoking_status'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    1
# 4    0
# Name: smoking_status, dtype: int64

# %% [markdown]
# # 3. Predictive Modelling

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %% [markdown]
# ## Splitting the data into test and train sets

# %%
train,test=train_test_split(data,test_size=0.3,random_state=0,stratify=data['stroke'])
train_X=train[train.columns[:-1]]
train_Y=train[train.columns[-1:]]
test_X=test[test.columns[:-1]]
test_Y=test[test.columns[-1:]]
X=data[data.columns[:-1]]
Y=data["stroke"]
len(train_X), len(train_Y), len(test_X), len(test_Y)
# Out:
# (3486, 3486, 1495, 1495)

# %%
print(train_X)
# Out:
#       gender  age_band  hypertension  heart_disease  avg_glucose_level  \
# 4103       0         4             0              0           0.316405
# 1999       1         0             0              0           0.303194
# 1074       1         4             0              0           0.250092
# 1264       1         3             0              0           0.325348
# 2914       1         3             0              0           0.329690
# ...      ...       ...           ...            ...                ...
# 1522       1         3             0              1           0.765622
# 2808       1         0             0              0           0.301465
# 4547       1         0             0              0           0.270406
# 4593       1         2             0              0           0.254140
# 1512       1         2             0              0           0.378634
#
#            bmi  smoking_status
# 4103  0.572597               3
# 1999  0.349693               1
# 1074  0.548057               3
# 1264  0.517382               0
# 2914  0.562372               3
# ...        ...             ...
# 1522  0.721881               2
# 2808  0.464213               3
# 4547  0.468303               3
# 4593  0.593047               2
# 1512  0.760736               0
#
# [3486 rows x 7 columns]

# %%
print(train_Y)
# Out:
#       stroke
# 4103       0
# 1999       0
# 1074       0
# 1264       0
# 2914       0
# ...      ...
# 1522       0
# 2808       0
# 4547       0
# 4593       0
# 1512       0
#
# [3486 rows x 1 columns]

# %% [markdown]
# ## Radial Support Vector Machines(rbf-SVM)

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
# Out:
# Accuracy for rbf SVM is  0.9505016722408027

# %% [markdown]
# ## Linear Support Vector Machine(linear-SVM)

# %%
model=svm.SVC(kernel='linear',C=0.1,gamma=0.1)
model.fit(train_X,train_Y)
prediction2=model.predict(test_X)
print('Accuracy for linear SVM is',metrics.accuracy_score(prediction2,test_Y))
# Out:
# Accuracy for linear SVM is 0.9505016722408027

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression()
model.fit(train_X,train_Y)
prediction3=model.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction3,test_Y))
# Out:
# The accuracy of the Logistic Regression is 0.9505016722408027

# %% [markdown]
# ## Decision Tree

# %%
model=DecisionTreeClassifier()
model.fit(train_X,train_Y)
prediction4=model.predict(test_X)
print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction4,test_Y))
# Out:
# The accuracy of the Decision Tree is 0.9103678929765886

# %% [markdown]
# ## K-Nearest Neighbours(KNN)

# %%
model=KNeighborsClassifier()
model.fit(train_X,train_Y)
prediction5=model.predict(test_X)
print('The accuracy of the KNN is',metrics.accuracy_score(prediction5,test_Y))
# Out:
# The accuracy of the KNN is 0.9444816053511705

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
model=GaussianNB()
model.fit(train_X,train_Y)
prediction6=model.predict(test_X)
print('The accuracy of the NaiveBayes is',metrics.accuracy_score(prediction6,test_Y))
# Out:
# The accuracy of the NaiveBayes is 0.862876254180602

# %% [markdown]
# ## Random Forests

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_Y)
prediction7=model.predict(test_X)
print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction7,test_Y))
# Out:
# The accuracy of the Random Forests is 0.9444816053511705

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
kfold = KFold(n_splits=10) # k=10, split the data into 10 equal parts
cv_mean=[]
accuracy=[]
std=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree','Naive Bayes','Random Forest']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(),GaussianNB(),RandomForestClassifier(n_estimators=100)]
for i in models:
    model = i
    cv_result = cross_val_score(model,X,Y, cv = kfold,scoring = "accuracy")
    cv_result=cv_result
    cv_mean.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':cv_mean,'Std':std},index=classifiers)
new_models_dataframe2
# Out:
#                       CV Mean       Std
# Linear Svm           0.950285  0.124694
# Radial Svm           0.950285  0.124694
# Logistic Regression  0.950285  0.124694
# KNN                  0.949080  0.124239
# Decision Tree        0.904099  0.108317
# Naive Bayes          0.859911  0.078227
# Random Forest        0.943056  0.121987

# %%
new_models_dataframe2['CV Mean'].plot.barh(width=0.8)
plt.title('Average CV Mean Accuracy')
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.show()

# %% [markdown]
# ## Great, Lets see the confusion matrixes for each algorithm

# %%
f,ax=plt.subplots(3,3,figsize=(12,10))
y_pred = cross_val_predict(svm.SVC(kernel='rbf'),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,0],annot=True,fmt='2.0f')
ax[0,0].set_title('Matrix for rbf-SVM')
y_pred = cross_val_predict(svm.SVC(kernel='linear'),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,1],annot=True,fmt='2.0f')
ax[0,1].set_title('Matrix for Linear-SVM')
y_pred = cross_val_predict(KNeighborsClassifier(n_neighbors=5),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,2],annot=True,fmt='2.0f')
ax[0,2].set_title('Matrix for KNN')
y_pred = cross_val_predict(RandomForestClassifier(n_estimators=100),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,0],annot=True,fmt='2.0f')
ax[1,0].set_title('Matrix for Random-Forests')
y_pred = cross_val_predict(LogisticRegression(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,1],annot=True,fmt='2.0f')
ax[1,1].set_title('Matrix for Logistic Regression')
y_pred = cross_val_predict(DecisionTreeClassifier(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,2],annot=True,fmt='2.0f')
ax[1,2].set_title('Matrix for Decision Tree')
y_pred = cross_val_predict(GaussianNB(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[2,0],annot=True,fmt='2.0f')
ax[2,0].set_title('Matrix for Naive Bayes')
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show()

# %% [markdown]
# ## Ensembling

# %% [markdown]
# Ensembling is a great method to increase the performance of a model. Actually, It is the combination of several simple models to create a single powerful model. We already got the 95% accuracy for some models but it is just to see the ensembling

# %%
from sklearn.ensemble import VotingClassifier
ensemble_lin_rbf=VotingClassifier(estimators=[('KNN',KNeighborsClassifier(n_neighbors=5)),
                                              ('RBF',svm.SVC(probability=True,kernel='rbf',C=0.5,gamma=0.1)),
                                              ('RFor',RandomForestClassifier(n_estimators=500,random_state=0)),
                                              ('LR',LogisticRegression(C=0.05)),
                                              ('DT',DecisionTreeClassifier(random_state=0)),
                                              ('NB',GaussianNB()),
                                              ('svm',svm.SVC(kernel='linear',probability=True))
                                             ],
                       voting='soft').fit(train_X,train_Y)
print('The accuracy for ensembled model is:',ensemble_lin_rbf.score(test_X,test_Y))
cross=cross_val_score(ensemble_lin_rbf,X,Y, cv = 10,scoring = "accuracy")
print('The cross validated score is :',cross.mean())
# Out:
# The accuracy for ensembled model is: 0.9505016722408027
# The cross validated score is : 0.9500100602812049

# %% [markdown]
# ## Boosting

# %% [markdown]
# It is also an ensembling technique that we will be applying some boosting algorithms like Ada, Gradient and XGBoost in this section

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier(n_estimators=200,random_state=0,learning_rate=0.1)
result=cross_val_score(ada,X,Y,cv=10,scoring='accuracy')
print('The cross validated score for AdaBoost is:',result.mean())
# Out:
# The cross validated score for AdaBoost is: 0.9502108634940564

# %%
from sklearn.ensemble import GradientBoostingClassifier
grad=GradientBoostingClassifier(n_estimators=500,random_state=0,learning_rate=0.1)
result=cross_val_score(grad,X,Y,cv=10,scoring='accuracy')
print('The cross validated score for Gradient Boosting is:',result.mean())
# Out:
# The cross validated score for Gradient Boosting is: 0.9423799406040997

# %%
import xgboost as xg
xgboost=xg.XGBClassifier(n_estimators=900,random_state=0, learning_rate=0.1)
result=cross_val_score(xgboost,X,Y,cv=10,scoring='accuracy')
print('The cross validated score for XGBoost is:',result.mean())
# Out:
# The cross validated score for XGBoost is: 0.9379634771551133
